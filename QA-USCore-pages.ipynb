# %%
import bs4, requests, re
import warnings
from bs4 import XMLParsedAsHTMLWarning
warnings.filterwarnings('ignore', category=XMLParsedAsHTMLWarning)

base_url = "https://build.fhir.org/ig/HL7/US-Core/"  # master

# to get a page list from the ig.resource use profile_list.ipynb
Pages = ['https://build.fhir.org/ig/HL7/US-Core/index.html',
 'https://build.fhir.org/ig/HL7/US-Core/conformance.html',
 'https://build.fhir.org/ig/HL7/US-Core/general-requirements.html',
 'https://build.fhir.org/ig/HL7/US-Core/must-support.html',
 'https://build.fhir.org/ig/HL7/US-Core/scopes.html',
 'https://build.fhir.org/ig/HL7/US-Core/security.html',
 'https://build.fhir.org/ig/HL7/US-Core/guidance.html',
 'https://build.fhir.org/ig/HL7/US-Core/uscdi.html',
 'https://build.fhir.org/ig/HL7/US-Core/general-guidance.html',
 'https://build.fhir.org/ig/HL7/US-Core/clinical-notes.html',
 'https://build.fhir.org/ig/HL7/US-Core/medication-list.html',
 'https://build.fhir.org/ig/HL7/US-Core/basic-provenance.html',
 'https://build.fhir.org/ig/HL7/US-Core/screening-and-assessments.html',
 'https://build.fhir.org/ig/HL7/US-Core/relationship-with-other-igs.html',
 'https://build.fhir.org/ig/HL7/US-Core/profiles-and-extensions.html',
 'https://build.fhir.org/ig/HL7/US-Core/capability-statements.html',
 'https://build.fhir.org/ig/HL7/US-Core/search-parameters-and-operations.html',
 'https://build.fhir.org/ig/HL7/US-Core/terminology.html',
 'https://build.fhir.org/ig/HL7/US-Core/vsacname-fhiruri-map.html',
 'https://build.fhir.org/ig/HL7/US-Core/examples.html',
 'https://build.fhir.org/ig/HL7/US-Core/downloads.html',
 'https://build.fhir.org/ig/HL7/US-Core/version-history.html',
 'https://build.fhir.org/ig/HL7/US-Core/changes.html',
 'https://build.fhir.org/ig/HL7/US-Core/changes-between-versions.html',
 'https://build.fhir.org/ig/HL7/US-Core/looking-ahead.html',
 'https://build.fhir.org/ig/HL7/US-Core/us-core-roadmap.html',
 'https://build.fhir.org/ig/HL7/US-Core/writing-vital-signs.html',
 'https://build.fhir.org/ig/HL7/US-Core/writing-clinical-notes.html',
 'https://build.fhir.org/ig/HL7/US-Core/patient-data-feed.html',
 'https://build.fhir.org/ig/HL7/US-Core/patient-data-feed-additional-resources.html',
 'https://build.fhir.org/ig/HL7/US-Core/ImplementationGuide-hl7.fhir.us.core.html']


# to get a profile list from the ig.resource use profile_list.ipynb
Profiles = ['https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-adi-documentreference.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-allergyintolerance.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-authentication-time.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-average-blood-pressure.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-birthsex.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-blood-pressure.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-bmi.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-body-height.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-body-temperature.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-body-weight.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-care-experience-preference.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-careplan.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-careteam.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-condition-encounter-diagnosis.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-condition-problems-health-concerns.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-coverage.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-device.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-diagnosticreport-lab.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-diagnosticreport-note.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-direct.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-documentreference.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-encounter.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-ethnicity.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-extension-questionnaire-uri.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-familymemberhistory.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-familymemberhistory-recorder.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-genderIdentity.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-goal.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-head-circumference.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-heart-rate.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-immunization.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-individual-sex.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-interpreter-needed.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-jurisdiction.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-observation-lab.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-location.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-medication-adherence.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-medication.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-medicationdispense.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-medicationrequest.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-observation-adi-documentation.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-observation-clinical-result.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-observation-occupation.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-observation-pregnancyintent.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-observation-pregnancystatus.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-observation-screening-assessment.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-observation-sexual-orientation.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-organization.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-patient.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-pediatric-bmi-for-age.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-head-occipital-frontal-circumference-percentile.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-pediatric-weight-for-height.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-pmo-servicerequest.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-practitioner.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-practitionerrole.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-procedure.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-provenance.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-pulse-oximetry.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-questionnaireresponse.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-race.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-relatedperson.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-respiratory-rate.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-servicerequest.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-sex.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-simple-observation.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-smokingstatus.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-specimen.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-treatment-intervention-preference.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-tribal-affiliation.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-uscdi-requirement.html',
 'https://build.fhir.org/ig/HL7/US-Core/StructureDefinition-us-core-vital-signs.html']

matches = {'text':'duplicate words' ,'re_list':[r'\b(\w+)(?:\W+\1\b)+',]}  #duplicate words  # TODO create a white list of words to ignore
# matches = {'text':'Bad MD links' ,'re_list':[r'\[.*?\]']} #bad md links # TODO create a white list of words to ignore
# matches = {'text':'Possible stray liquid tags or filters found' ,'re_list':[r'({%.*?%}|{{.*?}}|{%|%}|{{|}})',]}  #liquid tags, filter
# matches = {'text':'Possible stray  git or bash commands found' ,'re_list':['git st','git pu', 'git co', 'pig -i', 'pig -ien', 'pig -sy', 'git', 'pig' , 'pta']}  #git, bash
# matches = {'text':'Stray/malformed tags found:','re_list':['<.*?/>', ' .*?/>']}  # stray tags
# matches = {'text':'Stray/malformed tags found:','re_list':['</?[A-Za-z][A-Za-z0-9]*\b[^>]*>', '</?[A-Za-z][A-Za-z0-9]*\b[^>]*>', '<[^>]*|>[^<]*']} # stray tags # TODO create a white list of words to ignore
# matches = {'text':'Common Typos','re_list':[
#     "accomodation", "accommodaton",  # → accommodation
#     "definately", "definetly", "definitly",  # → definitely
#     "seperate", "seperat",  # → separate
#     "occured", "ocurred",  # → occurred
#     "recieve", "receieve",  # → receive
#     "embarass", "embarras",  # → embarrass
#     "occassion", "ocasion",  # → occasion
#     "wierd",  # → weird
#     "alot",  # → a lot
#     "publically",  # → publicly
#     "untill",  # → until
#     "maintainance", "maintenence",  # → maintenance
#     "independant", "independance",  # → independent
#     "equiptment",  # → equipment
#     "calender",  # → calendar
#     "neccessary", "necessery",  # → necessary
#     "teh",  # → the
#     "reciept",  # → receipt
#     "adress",  # → address
#     "agian",  # → again
#     "foward",  # → forward
#     "flexibilty",  # → flexibility
#     "it's"  # (when meant as "its" – context needed)
# ]}


# for page in Pages:
for page in Profiles:
  html = requests.get(page).text
  soup = bs4.BeautifulSoup(html, 'html.parser')
  visible_text = soup.get_text(separator='\n')  # Or ' ' for single string
  for match in matches['re_list']:
    stray_tags = re.findall(match, visible_text)
    if stray_tags:
        print(page)
        print(matches['text'])
        for index, tag in enumerate(sorted(set(stray_tags)), start=1):
            first_line = tag.splitlines()[0]  # Take only the first line
            print(f"{index}. {first_line}")
        print('--------------------------------------')


# TODO create a white list of words to ignore

# for page in Profiles:
        # response = requests.get(page)

        # soup = bs4.BeautifulSoup(response.text)
        # mypage = soup.get_text(' ', strip=True)
        # # print(soup.get_text('', strip=True))
        # for match in matches:
        #     mymatch = re.findall(match, mypage)
        #     if mymatch:
        #         print(page)
        #         print(mymatch)
        #         print('--------------------------------------')
            # else:
            #         print('no match')
            # print()
            # print(".")
